# %% [markdown]
# # 📘 8 – Proyecto Final Integrador

# %% [markdown]
# ## 🎯 Objetivos
# - Integrar IA en la nube (Azure u otras) con Streamlit en proyectos funcionales.
# - Diseñar soluciones intermedias–avanzadas que combinen texto, imagen y voz.
# - Aplicar buenas prácticas: secretos, caché, manejo de errores, despliegue.
# - Documentar, defender y desplegar el proyecto final.

# %% [markdown]
# ## 📖 Introducción
# Este proyecto integrador reúne todo lo aprendido. Se valora una solución útil, bien terminada y comprensible.

# %% [markdown]
# ## ✅ Requisitos mínimos (simplificados)
# - App con Streamlit (UI clara) y al menos 1 servicio/modelo de IA real.
# - Secretos seguros (`st.secrets` / variables de entorno). Nada de claves en el código.
# - Uso razonable de caché y gestión de errores (mensajes claros, reintentos cuando proceda).
# - Despliegue en Streamlit Cloud y Docker/Azure.
# - README.md con instrucciones y capturas.

# %% [markdown]
# ## 💡 Proyectos propuestos (intermedios–avanzados)

# %% [markdown]
# > Cada propuesta incluye objetivo, funcionalidades mínimas, arquitectura, APIs/Modelos (Azure + alternativas), páginas Streamlit, criterios de aceptación y ampliaciones.

# %% [markdown]
# ### 1) 🌍 Traductor multilingüe con voz (voz → texto → traducción → voz) (6)
#
# **Objetivo:** Capturar voz, transcribir, traducir y sintetizar audio en el idioma destino.
#
# **Funcionalidades mínimas**
# - Subida/grabación de audio corto (WAV/WEBM).
# - STT → Texto → Traducción → TTS.
# - Selector de idioma origen/destino y voz. (al menos 5 idiomas)
#
# **Arquitectura**
# 1. Streamlit (UI) → audio.
# 2. STT → texto.
# 3. Translate → texto destino.
# 4. TTS → MP3/OGG reproducible.
#
# **APIs/Modelos**
# - Azure: Speech-to-Text, Translator, Text-to-Speech.
# - Alternativas: Whisper (OpenAI/Replicate/Local), facebook/m2m100_418M (HF) + gTTS, Google Speech/TTS.
#
# **Ampliaciones**
# - Detección automática de idioma. (0.5)
# - Historial y descarga CSV. (1)
# - Subtítulos con timestamps. (1)

# %% [markdown]
# ### 2) 📸 Detector de objetos y etiquetas (6)
#
# **Objetivo:** Analizar imágenes (subida o URL) y devolver descripción, etiquetas y objetos con bounding boxes.
#
# **Mínimos**
# - Subir imagen/URL.
# - Mostrar caption, tags y objetos (con cajas).
#
# **Arquitectura**
# - Streamlit → imagen → Vision API → render de resultados.
#
# **APIs/Modelos**
# - Azure: Image Analysis 4.0 (features=caption,tags,objects).
# - Alternativas: Google Vision; HF (YOLOv5/8 para objetos + BLIP para caption).
#
# **Criterios**
# - Al menos 3 etiquetas y 1 objeto en foto de prueba.
# - Coordenadas correctamente dibujadas.
#
# **Ampliaciones**
# - Export JSON. (1)
# - Búsqueda por etiqueta en mini dataset local. (1)

# %% [markdown]
# ### 3) 🧠 Resumidor y análisis de sentimiento (7)
#
# **Objetivo:** Dado un texto largo, resumir y obtener sentimiento (y keyphrases).
#
# **Mínimos**
# - Entrada de texto (pegar/cargar .txt).
# - Resumen configurable (n frases) + sentimiento.
# - PDFs con OCR previo.
#
# **Arquitectura**
# - UI → Language API → resumen/sentimiento/keyphrases → UI.
#
# **APIs/Modelos**
# - Azure: Language (tasks).
# - Alternativas: OpenAI GPT; HF facebook/bart-large-cnn (resumen) y nlptown/bert-base-multilingual-uncased-sentiment.
#
# **Criterios**
# - Resumen ≤150 palabras con n configurable.
# - Sentimiento global + por frases.
#
# **Ampliaciones**
# - Comparar dos textos (lado a lado). (1)

# %% [markdown]
# ### 4) 🎧 Transcriptor de podcasts/clases (con resumen) (8)
#
# **Objetivo:** Procesar audios largos, transcribir con timestamps y resumir en bullet points.
#
# **Mínimos**
# - Subir MP3/WAV (hasta X min).
# - Transcripción con timestamps.
# - Resumen por bloques.
#
# **Arquitectura**
# - UI → STT (batch) → JSON con timestamps → Summarization → UI.
#
# **APIs/Modelos**
# - Azure: Speech-to-Text (batch) + Language Summarization.
# - Alternativas: AssemblyAI/Deepgram; Whisper + resumen con OpenAI/HF.
#
# **Ampliaciones**
# - Diarización (hablantes). (1)
# - Export SRT/VTT. (1)

# %% [markdown]
# ### 5) 💬 Chatbot temático con RAG (documentos propios) (10)
#
# **Objetivo:** Q&A sobre un corpus propio con búsqueda semántica y respuestas citadas.
#
# **Mínimos**
# - Subir documentos (PDF/TXT).
# - Indexar (embeddings) y recuperar pasajes (top-k).
# - Respuesta con citas (IDs/páginas).
#
# **Arquitectura**
# 1. Ingesta → embeddings → vector store (FAISS/Chroma).
# 2. Consulta → retrieve → LLM genera respuesta citada.
#
# **APIs/Modelos**
# - Azure: Azure OpenAI (embeddings + chat).
# - Alternativas: OpenAI + FAISS/Chroma; HF + Mistral/Llama (Replicate/Local).
#
# **Páginas**
# - “Documentos”.
# - “Chat con citas”.
#
# **Criterios**
# - Muestra fuentes siempre.
# - Respuesta “no encontrado” honesta.
#
# **Ampliaciones**
# - Roles de sistema.
# - Export del chat.

# %% [markdown]
# ### 6) 📰 Analizador de noticias / verificador básico (10)
#
# **Objetivo:** Dada una noticia/URL, detectar idioma, sentimiento, resumen y red flags (heurísticas).
#
# **Mínimos**
# - Entrada: URL o texto.
# - Detección de idioma + resumen + sentimiento.
# - Heurísticas simples (clickbait, palabras sesgo).
#
# **Arquitectura**
# - UI → fetch + extract → Language (detection/sentiment/summarization) → score heurístico.
#
# **APIs/Modelos**
# - Azure: Language.
# - Alternativas: OpenAI/HF para resumen/sentimiento; BeautifulSoup para scraping.
#
# **Páginas**
# - “URL / Texto”.
# - “Informe” (idioma, resumen, sentimiento, red flags).
#
# **Criterios**
# - Informe con evidencias (frases/fragmentos).
#
# **Ampliaciones**
# - Clasificador binario fake/sátira/informativo (con disclaimers).
# - Historial de análisis.

# %% [markdown]
# ### 7) 🖼️ Buscador visual por similitud (10)
#
# **Objetivo:** Dada una imagen, encontrar similares por embeddings o etiquetas.
#
# **Mínimos**
# - Dataset local (assets/).
# - Indexación por embeddings/tags.
# - Consulta: top-k similares con score.
#
# **Arquitectura**
# - Preproceso → embeddings (CLIP/Vision) → vector store → similitud → grid UI.
#
# **APIs/Modelos**
# - Azure: Vision (tags) + (opcional) embeddings con Azure OpenAI (CLIP-like).
# - Alternativas: HF openai/clip-vit-base-patch32; Google Vision labels.
#
# **Páginas**
# - “Indexar”.
# - “Buscar”.
#
# **Ampliaciones**
# - Filtro por etiquetas.
# - Búsqueda por texto (“playa al atardecer”).

# %% [markdown]
# ### 8) 🗣️ Tutor de pronunciación en inglés (10)
#
# **Objetivo:** Evaluar pronunciación con score global y por palabra + sugerencias.
#
# **Mínimos**
# - Grabar audio leyendo una frase modelo.
# - Evaluación de pronunciación.
#
# **Arquitectura**
# - UI → audio → Pronunciation Assessment → JSON → feedback UI.
#
# **APIs/Modelos**
# - Azure: Speech – Pronunciation Assessment.
# - Alternativas: Deepgram (pronunciation); forced alignment (avanzado).
#
# **Páginas**
# - “Frase y grabación”.
# - “Resultados y recomendaciones”.
#
# **Criterios**
# - Score global + por palabra.
# - ≥3 sugerencias útiles.
#
# **Ampliaciones**
# - Historial por usuario.
# - Plan de práctica progresivo.

# %% [markdown]
# ### 9) 🎵 Generador de audioguías multilingües (8)
#
# **Objetivo:** Crear audioguías desde texto con traducción y TTS (control de pausas/énfasis).
#
# **Mínimos**
# - Editor de texto.
# - Traducción + TTS (3 idiomas).
# - Descarga MP3.
#
# **Arquitectura**
# - Texto → (Translator) → TTS (SSML) → lista de audios.
#
# **APIs/Modelos**
# - Azure: Translator + Text-to-Speech (SSML).
# - Alternativas: gTTS; ElevenLabs (pago).
#
# **Criterios**
# - Soporte SSML simple (pausas <break>).
# - 3 voces distintas.
#
# **Ampliaciones**
# - Modo “tour” (paradas). (1)
# - Export ZIP con guion + audios. (1)

# %% [markdown]
# ## 🧠 Proyecto libre del alumnado
# **Validación previa**
# - Problema y valor aportado.
# - Servicio(s) de IA y justificación.
# - Flujo entrada→IA→salida y riesgos (coste, límites).
#
# **Evaluación**
# - Misma rúbrica que el resto.

# %% [markdown]
# ## 📄 Entregables
# 1. Repo GitHub con README y capturas/gifs.
# 2. Despliegue (URL Azure) o Docker + vídeo.
# 3. Gestión de secretos (st.secrets / .env.example).
# 4. Informe breve: arquitectura, servicios usados, coste estimado, límites.

# %% [markdown]
# ## 🧮 Rúbrica (100 pts)
# | Criterio | Detalle | Puntos |
# |---|---|---|
# | Funcionalidad | Flujos clave probados | **25** |
# | Integración IA | Uso correcto de 1+ servicios/modelos | **20** |
# | Diseño/UX | UI clara y feedback | **10** |
# | Calidad de código | Estructura razonable, caché, errores | **15** |
# | Despliegue/secretos | Config segura y despliegue funcional | **10** |
# | Innovación/valor | Originalidad y utilidad real | **10** |
# | Documentación/defensa | README + demo + explicación | **10** |
# | **Total** |  | **100** |

# %% [markdown]
# ## 🚀 Consejos para despliegue y defensa
# - Streamlit Cloud: configura Secrets; revisa logs al fallar.
# - Docker/Azure: variables de entorno en runtime; imágenes ligeras.
# - Defensa: 8–10 min + preguntas.
